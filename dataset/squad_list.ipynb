# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
from pathlib import Path

root_path = Path().resolve().parent
current_path = Path().resolve()
print("Root path:", root_path)
print("Current path:", current_path)
# Out:
# Root path: P:\programs\DSML\the_birthday_paradox_in_sports

# %%
pdf_path = root_path / "dataset" / "SquadLists-English.pdf"
print("PDF Path:", pdf_path)
pdf_name = pdf_path.name
print("PDF Name:", pdf_name)
pdf_name_without_ext = pdf_path.stem
print("PDF Name without extension:", pdf_name_without_ext)
# Out:
# PDF Path: P:\programs\DSML\the_birthday_paradox_in_sports\dataset\SquadLists-English.pdf
# PDF Name: SquadLists-English.pdf
# PDF Name without extension: SquadLists-English

# %%
from utils.DoclingTableExtractor import DoclingTableExtractor


extractor = DoclingTableExtractor(pdf_path)
dfs = extractor.get_dataframes()

# extractor.export_csv(current_path / (pdf_name_without_ext + "_tables.csv"))
# extractor.export_json(current_path / (pdf_name_without_ext + "_tables.json"))
# Out:
# 2025-12-27 12:32:19,351 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-12-27 12:32:20,305 - INFO - Going to convert document batch...
# 2025-12-27 12:32:20,305 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2025-12-27 12:32:20,321 - INFO - Loading plugin 'docling_defaults'
# 2025-12-27 12:32:20,343 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-12-27 12:32:20,348 - INFO - Loading plugin 'docling_defaults'
# 2025-12-27 12:32:20,419 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-12-27 12:32:20,582 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2025-12-27 12:32:20,583 - INFO - easyocr cannot be used because it is not installed.
# 2025-12-27 12:32:21,788 - INFO - Accelerator device: 'cpu'
# [INFO] 2025-12-27 12:32:21,802 [RapidOCR] base.py:22: Using engine_name: torch
# ...
